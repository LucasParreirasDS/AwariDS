# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasParreirasDS/AwariDS/blob/main/Banco%20de%20Dados%20e%20SQL/%5BAWARI_DS_06_02%5D_Pr%C3%A1tica_SQL_com_Python_e_SQLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![header-notebooks.png](data:image/png;base64,...)
#
# Prática da **Aula 06: Coleta de Dados II**, do curso de **Data Science** da **[Awari](https://awari.com.br/)**. Para utilizá-la, vá no menu "Arquivo" e, em seguida, na opção "Salvar uma cópia no Drive". Isto criará uma cópia deste notebook em uma pasta chamada "Colab Notebooks", no seu Google Drive pessoal. Use a cópia para criar novas células de código ou executar as células desta prática.
#
# ---

# %% [markdown]
# # **SQL com Python e SQLite**

# %% [markdown]
# ## **O que é SQL?**
#
# **SQL** significa *Structured Query Language*, ou "Linguagem de Consulta Estruturada". Resumidamente, é uma linguagem de programação para lidar com banco de dados relacionais (baseado em tabelas).

# %% [markdown]
# ## **O que é SQLite?**
#
# **SQLite** é um banco de dados relacional que, diferentemente de outras ferramentas do tipo, não armazena informações em um servidor.
#
# Essa independência acontece porque ele consegue colocar os seus arquivos dentro de si próprio.
#
# A documentação de SQLite está disponível em: https://docs.python.org/3/library/sqlite3.html.

# %% [markdown]
# ## **SQL com SLite na prática**
#
# A partir daqui, vamos importar o SQLite e aprender como usar a linguagem SQL.
#
# Note que SQL não é usada apenas no banco de dados SQLite, mas em qualquer banco de dados relacional, como MySQL, Postgres, entre outros.
#
# Aprendê-la, portanto, garante meios de lidar com diversos softwares de bancos de dados.

# %% [markdown]
# ### **Instalação e importação de pacotes**
#
# O primeiro passo é instalar as bibliotecas **Pandas** e **SQLite** para uso nesta prática:

# %%
# Importando Pandas e SQLite3
import pandas as pd
import sqlite3

# %% [markdown]
# O passo a seguir será necessário para etapas adiante nesta nossa prática. Ele instala um recurso para podermos ler arquivos do Microsoft Excel (com a extensão ".xls") no Google Colab.

# %%
# Instalando recurso para ler ".xls" no Google Colab
# !pip install --upgrade xlrd
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (2.0.1)

# %% [markdown]
# Com isto, podemos começar a praticar.

# %% [markdown]
# ### **Criando um banco de dados no SQLite3**
#
# O SQLite3 é um sistema de banco de dados. Para usá-lo, precisamos, primeiro, criar um banco de dados dentro dele para uso. Fazemos isso da seguinte forma:

# %%
# Seta conexão com o SQLite
con  = sqlite3.connect('teste.db')

# %%
# Cria um cursor (recurso do SQLite) para executar instruções SQL
cur = con.cursor()

# %% [markdown]
# ### **Criando tabelas no banco de dados**
#
# Agora, podemos criar tabelas no banco de dados. A sintaxe (forma de escrita) em SQL para isso está descrita a seguir.
#
# **Sintaxe:**
#
# ```
# CREATE TABLE nome_da_tabela (
#     coluna1 tipo_dados,
#     coluna2 tipo_dados,
#     coluna3 tipo_dados,
#    ....
# )
# ```
#
# Os parâmetros ```coluna``` especificam os nomes das colunas da tabela, enquanto os parâmetros ```tipo_dados``` especifica o tipo de dados que a coluna pode conter (por exemplo, ```varchar``` para sequências de caracteres, ```integer``` para números inteiros, ```date``` para datas etc.).
#
# Usamos o método `execute` do cursor para executar instruções.

# %%
# Criando uma tabela
cur.execute(
    'CREATE TABLE teste ( nome varchar, idade integer, cpf integer(11) )'
)

# Confirmando a criação da tabela
con.commit()

# %%
# Criando outra tabela
cur.execute(
    'CREATE TABLE outratabela ( nome varchar, idade integer, cpf integer(11) )'
)

# Confirmando a criação desta outra tabela
con.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-4fc5c06c693b> in <cell line: 2>()
#       1 # Criando outra tabela
# ----> 2 cur.execute(
#       3     'CREATE TABLE outratabela ( nome varchar, idade integer, cpf integer(11) )'
#       4 )
#       5
#
# OperationalError: table outratabela already exists

# %% [markdown]
# #### **Verificando se as tabelas foram criadas**
#
# Podemos verificar se a nova tabela foi criada consultando a tabela incorporada ao SQLite chamada `sqlite_master`, que agora deve conter uma entrada `teste`.
#
# Utilizaremos o método `fetchall()` para retornar todas as linhas de um resultado de uma consulta dentro de uma lista.

# %%
# Verificando se as tabelas foram criadas
cur.execute("SELECT name FROM sqlite_master").fetchall()
# Out:
# [('teste',), ('outratabela',)]

# %% [markdown]
# ### **CRUD (*Create*, *Read*, *Update*, *Delete*)**
#
# A seguir, vamos ver as quatro operações fundamentais feitas em bancos de dados, apelidada de **CRUD**, iniciais das seguintes ações:
#
# - **C**reate: ato de criar (ou inserir) dados em um banco de dados;
# - **R**read: ato de ler (ou "selecionar" ou, ainda, exibir) dados registrados um banco de dados;
# - **U**pdate: ato de atualizar (alterar, modificar, substituir etc.) dados registrados um banco de dados;
# - **D**elete: ato de excluir dados registrados um banco de dados.

# %% [markdown]
# #### **Inserindo dados em uma tabela já criada**
#
# ```INSERT INTO``` é a instrução SQL usada para inserir novos registros em uma tabela. É a ação *create* do CRUD.
#
# **Sintaxe:**
#
# ```
# INSERT INTO nome_da_tabela  (coluna1, coluna2, coluna3, ...)
# ```

# %%
## Inserindo dados na tabela "testes"
cur.execute("""
          INSERT INTO teste VALUES
            ('Fulano de tal', 35, 12345678910),
            ('Fulana Ana', 40, 12345678911)
          """)

## Confirmando a ação
con.commit()

# %% [markdown]
# #### **Selecionando registros de uma tabela**
#
# ```SELECT``` é a instrução SQL para selecionar dados de um banco de dados. É a ação *read* do CRUD.
#
# **Sintaxe:**
#
# ```
# SELECT * FROM nome_da_tabela
# SELECT coluna1, coluna1, coluna3, ... FROM nome_da_tabela
# ```

# %%
# Exibindo todos os registros da tabela teste
cur.execute("SELECT * FROM teste").fetchall()
# Out:
# [('Fulano de tal', 35, 12345678910), ('Fulana Ana', 40, 12345678911)]

# %%
# Exibindo apenas os registros "nome" e "idade" da tabela teste
cur.execute("SELECT nome, idade FROM teste").fetchall()
# Out:
# [('Fulano de tal', 35), ('Fulana Ana', 40)]

# %% [markdown]
# #### **Atualizando dados de uma tabela**
#
# ```UPDATE``` é a instrução SQL para modificar os registros existentes em uma tabela. É a ação *update* do CRUD.
#
# **Sintaxe:**
#
# ```
# UPDATE nome_da_tabela
# SET coluna_que_deseja_mudar = 'novo_valor'
# WHERE coluna_condicional IS NOT NULL
# ```

# %%
# Atualizando dados da tabela teste
cur.execute(
'''
UPDATE teste
SET idade = '36'
WHERE nome = 'Fulano de tal'
'''
).fetchall()
# Out:
# []

# %%
# Exibindo a atualização realizada
cur.execute(
'''
SELECT idade
FROM teste
WHERE nome = 'Fulano de tal'
'''
).fetchall()
# Out:
# [(36,)]

# %% [markdown]
# #### **Deletando dados em tabelas**
#
# ```DELETE``` é a instrução usada para excluir registros existentes em uma tabela. É a ação *delete* do CRUD.
#
# **Sintaxe:**
#
# ```
# DELETE from nome_da_tabela
# WHERE coluna_desejada = 'valor_condição_para_exclusão'
# ```

# %%
# Excluindo registros de uma tabela
cur.execute(
'''
DELETE from teste
WHERE nome = 'Fulana Ana'
'''
).fetchall()
# Out:
# []

# %%
# Excluindo todos os registros que restaram na tabela
cur.execute(
'''
SELECT *
FROM teste
'''
).fetchall()
# Out:
# [('Fulano de tal', 36, 12345678910)]

# %% [markdown]
# ## **Usando Pandas para realizar consultas**
#
# A partir daqui, vamos usar o Pandas, em conjunto com o SQLite, para realizar operações no banco de dados.
#
# Para isso, primeiro, vamos importar um arquivo ".xls" (formato do Microfost Excel), com o qual alimentaremos um banco de dados.

# %% [markdown]
# ### **Importando arquivo .xls**
#
# O arquivo que usaremos se chama [Global Store.xls](https://docs.google.com/spreadsheets/d/197zdFw9qpF4tyEBt-hu2NjJBRkbJm4b-/edit?usp=share_link&ouid=116814618168396531193&rtpof=true&sd=true). Clique no link para acessá-lo.
#
# Você pode copiá-lo para seu Google Drive ou fazer download dele para seu computador e depois fazer upload para o Google Drive.
#
# Lembre-se de salvá-lo ou fazer upload na pasta raiz (pasta inicial) de seu Google Drive ou dentro da pasta "Colab Notebooks", já que facilita o uso no Colab.
#
# **Também no Kaggle**
#
# O arquivo também está disponível no Kaggle, como [Global Superstore](https://www.kaggle.com/datasets/shekpaul/global-superstore), um conjunto de dados disponível para análises estatísticas e visualizações.
#
# Lá, porém, o arquivo está em formato ".zip" e é necessário descompactá-lo para poder usá-lo.

# %% [markdown]
# #### **Montagem do drive**
#
# Para acessarmos arquivos do Google Drive no Colab, é preciso repetir os passos vistos na aula anterior, relativos à montagem do drive. Para isso, executamos:

# %%
# Carrega biblioteca necessária
from google.colab import drive

# Montagem do drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Carregando o arquivo "Global Superstore.xls"**
#
# Vamos, então, carregar o arquivo "Global Superstore.xls" para um DataFrame do Pandas:

# %%
# Carregando a primeira aba da planilha
df_orders = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Global Superstore.xls', sheet_name = 0)

# Exibindo as colunas e primeiras linhas do DataFrame
df_orders.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
# Carregando a segunda aba da planilha
df_returns = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Global Superstore.xls', sheet_name=1)

# Exibindo as colunas e primeiras linhas do DataFrame
df_returns.head()
# Out:
#   Returned         Order ID         Market
# 0      Yes   MX-2013-168137          LATAM
# 1      Yes   US-2011-165316          LATAM
# 2      Yes  ES-2013-1525878             EU
# 3      Yes   CA-2013-118311  United States
# 4      Yes  ES-2011-1276768             EU

# %%
# Carregando a terceira aba da planilha
df_people = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Global Superstore.xls', sheet_name=2)

# Exibindo as colunas e primeiras linhas do DataFrame
df_people.head()
# Out:
#               Person   Region
# 0      Anna Andreadi  Central
# 1        Chuck Magee    South
# 2     Kelly Williams     East
# 3     Matt Collister     West
# 4  Deborah Brumfield   Africa

# %% [markdown]
# Abaixo, vamos fazer alguma limpeza e transformação de dados para facilitar o uso deles.
#
# Na prática, estamos substituindo espaços em branco por underlines (```_```) e hífens por vírgulas, no DataFrames que criamos com os dados da planilha.

# %%
# Limpando e transformando dados para facilitar o uso
df_orders.columns = df_orders.columns.str.replace(' ', '_').str.replace('-','').str.lower()
df_returns.columns = df_returns.columns.str.replace(' ', '_').str.replace('-','').str.lower()
df_people.columns = df_people.columns.str.replace(' ', '_').str.replace('-','').str.lower()

# %% [markdown]
# ### **Conectando o SQLite e criando tabelas a partir dos DataFrames**

# %%
# Conectando-se ao SQLite
bd = sqlite3.connect('superstore.db')

# Criando tabelas nos bancos de dados a partir dos nossos DataFrames
df_orders.to_sql('orders', bd, index=False, if_exists='replace')
df_returns.to_sql('returns', bd, index=False, if_exists='replace')
df_people.to_sql('people', bd, index=False, if_exists='replace')
# Out:
# 13

# %%
# Criando uma função para facilitar instruções SQL
def executaQuery(query):
  return pd.read_sql(query,bd)

# %% [markdown]
# A partir daqui, podemos executar SQL dentro do Pandas, o que torna nosso trabalho muito mais fluido.

# %% [markdown]
# ### **Comandos básicos SQL**
#
# Estes são os comandos básicos do SQL. Praticaremos cada um na sequência.
#
# * SELECT
# * FROM
# * LIMIT
# * ALIAS
# * WHERE
# * AND, OR, NOT
# * IN
# * LIKE
# * BETWEEN
# * DISTINCT
# * MIN, MAX, COUNT, AVG e SUM
# * ORDER BY
# * GROUP BY
# * JOINS
#
# Detalhe: não é obrigatório escrever os comandos em letras maiúsculas, mas, por convenção da comunidade mundial de SQL, ao longo de décadas, tornou-se padrão usar sempre maísculas. Por isso, manteremos tal convenção.

# %% [markdown]
# #### **SELECT e FROM**
#
# - Os principais comandos de consulta SQL são `SELECT` e `FROM`:
#
# - `SELECT` seleciona as colunas que queremos trazer
# - `FROM` seleciona a tabela que analisaremos
#
# Usar um asterisco (`*`) com ```SELECT```  permite selecionar toda das colunas.

# %%
# Usando SELECT * FROM
executaQuery('SELECT * FROM orders')
# Out:
#        row_id         order_id           order_date            ship_date  \
# 0       32298   CA-2012-124891  2012-07-31 00:00:00  2012-07-31 00:00:00
# 1       26341    IN-2013-77878  2013-02-05 00:00:00  2013-02-07 00:00:00
# 2       25330    IN-2013-71249  2013-10-17 00:00:00  2013-10-18 00:00:00
# 3       13524  ES-2013-1579342  2013-01-28 00:00:00  2013-01-30 00:00:00
# 4       47221     SG-2013-4320  2013-11-05 00:00:00  2013-11-06 00:00:00
# ...       ...              ...                  ...                  ...
# 51285   29002    IN-2014-62366  2014-06-19 00:00:00  2014-06-19 00:00:00
# 51286   35398   US-2014-102288  2014-06-20 00:00:00  2014-06-24 00:00:00
# 51287   40470   US-2013-155768  2013-12-02 00:00:00  2013-12-02 00:00:00
# 51288    9596   MX-2012-140767  2012-02-18 00:00:00  2012-02-22 00:00:00
# 51289    6147   MX-2012-134460  2012-05-22 00:00:00  2012-05-26 00:00:00
#
#             ship_mode customer_id     customer_name      segment  \
# 0            Same Day    RH-19495       Rick Hansen     Consumer
# 1        Second Class    JR-16210     Justin Ritter    Corporate
# 2         First Class    CR-12730      Craig Reiter     Consumer
# 3         First Class    KM-16375  Katherine Murray  Home Office
# 4            Same Day     RH-9495       Rick Hansen     Consumer
# ...               ...         ...               ...          ...
# 51285        Same Day    KE-16420   Katrina Edelman    Corporate
# 51286  Standard Class    ZC-21910  Zuschuss Carroll     Consumer
# 51287        Same Day    LB-16795    Laurel Beltran  Home Office
# 51288  Standard Class    RB-19795        Ross Baird  Home Office
# 51289    Second Class    MC-18100     Mick Crebagga     Consumer
#
#                 city            state  ...        product_id         category  \
# 0      New York City         New York  ...   TEC-AC-10003033       Technology
# 1         Wollongong  New South Wales  ...   FUR-CH-10003950        Furniture
# 2           Brisbane       Queensland  ...   TEC-PH-10004664       Technology
# 3             Berlin           Berlin  ...   TEC-PH-10004583       Technology
# 4              Dakar            Dakar  ...  TEC-SHA-10000501       Technology
# ...              ...              ...  ...               ...              ...
# 51285           Kure        Hiroshima  ...   OFF-FA-10000746  Office Supplies
# 51286        Houston            Texas  ...   OFF-AP-10002906  Office Supplies
# 51287         Oxnard       California  ...   OFF-EN-10001219  Office Supplies
# 51288       Valinhos        São Paulo  ...   OFF-BI-10000806  Office Supplies
# 51289       Tipitapa          Managua  ...   OFF-PA-10004155  Office Supplies
#
#        subcategory                                       product_name  \
# 0      Accessories  Plantronics CS510 - Over-the-Head monaural Wir...
# 1           Chairs          Novimex Executive Leather Armchair, Black
# 2           Phones                  Nokia Smart Phone, with Caller ID
# 3           Phones                     Motorola Smart Phone, Cordless
# 4          Copiers                     Sharp Wireless Fax, High-Speed
# ...            ...                                                ...
# 51285    Fasteners                      Advantus Thumb Tacks, 12 Pack
# 51286   Appliances  Hoover Replacement Belt for Commercial Guardsm...
# 51287    Envelopes       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes
# 51288      Binders                            Acco Index Tab, Economy
# 51289        Paper            Eaton Computer Printout Paper, 8.5 x 11
#
#           sales quantity discount    profit  shipping_cost  order_priority
# 0      2309.650        7      0.0  762.1845        933.570        Critical
# 1      3709.395        9      0.1 -288.7650        923.630        Critical
# 2      5175.171        9      0.1  919.9710        915.490          Medium
# 3      2892.510        5      0.1  -96.5400        910.160          Medium
# 4      2832.960        8      0.0  311.5200        903.040        Critical
# ...         ...      ...      ...       ...            ...             ...
# 51285    65.100        5      0.0    4.5000          0.010          Medium
# 51286     0.444        1      0.8   -1.1100          0.010          Medium
# 51287    22.920        3      0.0   11.2308          0.010            High
# 51288    13.440        2      0.0    2.4000          0.003          Medium
# 51289    61.380        3      0.0    1.8000          0.002            High
#
# [51290 rows x 24 columns]

# %% [markdown]
# #### **LIMIT**
#
# Para facilitar a consulta, podemos aplicar `LIMIT`, que define o número de linhas que a query irá trazer.
#
# Podemos usar `LIMIT` para mostrar as primeiras `n` linhas:

# %%
# Usando LIMITE com SELECT
executaQuery('SELECT * FROM orders LIMIT 5')
# Out:
#    row_id         order_id           order_date            ship_date  \
# 0   32298   CA-2012-124891  2012-07-31 00:00:00  2012-07-31 00:00:00
# 1   26341    IN-2013-77878  2013-02-05 00:00:00  2013-02-07 00:00:00
# 2   25330    IN-2013-71249  2013-10-17 00:00:00  2013-10-18 00:00:00
# 3   13524  ES-2013-1579342  2013-01-28 00:00:00  2013-01-30 00:00:00
# 4   47221     SG-2013-4320  2013-11-05 00:00:00  2013-11-06 00:00:00
#
#       ship_mode customer_id     customer_name      segment           city  \
# 0      Same Day    RH-19495       Rick Hansen     Consumer  New York City
# 1  Second Class    JR-16210     Justin Ritter    Corporate     Wollongong
# 2   First Class    CR-12730      Craig Reiter     Consumer       Brisbane
# 3   First Class    KM-16375  Katherine Murray  Home Office         Berlin
# 4      Same Day     RH-9495       Rick Hansen     Consumer          Dakar
#
#              state  ...        product_id    category  subcategory  \
# 0         New York  ...   TEC-AC-10003033  Technology  Accessories
# 1  New South Wales  ...   FUR-CH-10003950   Furniture       Chairs
# 2       Queensland  ...   TEC-PH-10004664  Technology       Phones
# 3           Berlin  ...   TEC-PH-10004583  Technology       Phones
# 4            Dakar  ...  TEC-SHA-10000501  Technology      Copiers
#
#                                         product_name     sales quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   discount    profit  shipping_cost  order_priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %% [markdown]
# Se não quisermos trazer todas as colunas, podemos trazer as colunas desejadas uma a uma, separadas por vírgulas:

# %%
# Selecionado as colunas "cliente" (customer_name) e "cidade" (city)
consulta = '''
           SELECT customer_name,
                  city
           FROM orders
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#       customer_name           city
# 0       Rick Hansen  New York City
# 1     Justin Ritter     Wollongong
# 2      Craig Reiter       Brisbane
# 3  Katherine Murray         Berlin
# 4       Rick Hansen          Dakar

# %%
# Selecionando todas as categorias
consulta = '''
           SELECT category
           FROM orders
           '''
executaQuery(consulta)
# Out:
#               category
# 0           Technology
# 1            Furniture
# 2           Technology
# 3           Technology
# 4           Technology
# ...                ...
# 51285  Office Supplies
# 51286  Office Supplies
# 51287  Office Supplies
# 51288  Office Supplies
# 51289  Office Supplies
#
# [51290 rows x 1 columns]

# %% [markdown]
# #### **ALIAS**
#
# Aliases SQL são usados ​​para fornecer um nome temporário a uma tabela ou coluna de uma tabela.
#
# São úteis para tornar nomes de colunas mais legíveis e ficam disponiveis uma determinada consulta por meio do comando `AS`.
#
# **Sintaxe:**
#
# ```
# SELECT coluna1 AS col1,
#        coluna2 AS col2
# FROM nome_da_tabela
# ```

# %%
# Selecionado as colunas "cliente" (customer_name) e "cidade" (city) com ALIAS (AS)
consulta = '''
           SELECT customer_name AS name,
                  city
           FROM orders
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#                name           city
# 0       Rick Hansen  New York City
# 1     Justin Ritter     Wollongong
# 2      Craig Reiter       Brisbane
# 3  Katherine Murray         Berlin
# 4       Rick Hansen          Dakar

# %% [markdown]
# #### **WHERE**
#
#
# A cláusula ou comando `WHERE` permite filtar registros. Dentro dela, também temos algumas condições que podemos executar.

# %% [markdown]
# ##### **Igual `=`**
#
# O símbolo `=` significa "igualdade", ou seja, selecionaremos todos os registros que sejam iguais ao valor informado.

# %%
# Selecionar todas as linhas onde a categoria for igual a "Technology"
consulta = '''
           SELECT *
           FROM orders
           WHERE category = 'Technology'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#    row_id         order_id           order_date            ship_date  \
# 0   32298   CA-2012-124891  2012-07-31 00:00:00  2012-07-31 00:00:00
# 1   25330    IN-2013-71249  2013-10-17 00:00:00  2013-10-18 00:00:00
# 2   13524  ES-2013-1579342  2013-01-28 00:00:00  2013-01-30 00:00:00
# 3   47221     SG-2013-4320  2013-11-05 00:00:00  2013-11-06 00:00:00
# 4   22732    IN-2013-42360  2013-06-28 00:00:00  2013-07-01 00:00:00
#
#       ship_mode customer_id     customer_name      segment           city  \
# 0      Same Day    RH-19495       Rick Hansen     Consumer  New York City
# 1   First Class    CR-12730      Craig Reiter     Consumer       Brisbane
# 2   First Class    KM-16375  Katherine Murray  Home Office         Berlin
# 3      Same Day     RH-9495       Rick Hansen     Consumer          Dakar
# 4  Second Class    JM-15655       Jim Mitchum    Corporate         Sydney
#
#              state  ...        product_id    category  subcategory  \
# 0         New York  ...   TEC-AC-10003033  Technology  Accessories
# 1       Queensland  ...   TEC-PH-10004664  Technology       Phones
# 2           Berlin  ...   TEC-PH-10004583  Technology       Phones
# 3            Dakar  ...  TEC-SHA-10000501  Technology      Copiers
# 4  New South Wales  ...   TEC-PH-10000030  Technology       Phones
#
#                                         product_name     sales quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1                  Nokia Smart Phone, with Caller ID  5175.171        9
# 2                     Motorola Smart Phone, Cordless  2892.510        5
# 3                     Sharp Wireless Fax, High-Speed  2832.960        8
# 4                Samsung Smart Phone, with Caller ID  2862.675        5
#
#   discount    profit  shipping_cost  order_priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1  919.9710         915.49          Medium
# 2      0.1  -96.5400         910.16          Medium
# 3      0.0  311.5200         903.04        Critical
# 4      0.1  763.2750         897.35        Critical
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### **Diferente `<>`**
#
# O símbolo `<>` significa "diferente", ou seja, selecionaremos todos os registros que sejam diferentes do valor informado.

# %%
# Selecionar todas as linhas onde a categoria for diferente a "Technology"
consulta = '''
           SELECT *
           FROM orders
           WHERE category <> 'Technology'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#    row_id        order_id           order_date            ship_date  \
# 0   26341   IN-2013-77878  2013-02-05 00:00:00  2013-02-07 00:00:00
# 1   30570   IN-2011-81826  2011-11-07 00:00:00  2011-11-09 00:00:00
# 2   31192   IN-2012-86369  2012-04-14 00:00:00  2012-04-18 00:00:00
# 3   40155  CA-2014-135909  2014-10-14 00:00:00  2014-10-21 00:00:00
# 4   40936  CA-2012-116638  2012-01-28 00:00:00  2012-01-31 00:00:00
#
#         ship_mode customer_id  customer_name    segment        city  \
# 0    Second Class    JR-16210  Justin Ritter  Corporate  Wollongong
# 1     First Class    TS-21340  Toby Swindell   Consumer     Porirua
# 2  Standard Class    MB-18085     Mick Brown   Consumer    Hamilton
# 3  Standard Class    JW-15220      Jane Waco  Corporate  Sacramento
# 4    Second Class    JH-15985    Joseph Holt   Consumer     Concord
#
#              state  ...       product_id         category subcategory  \
# 0  New South Wales  ...  FUR-CH-10003950        Furniture      Chairs
# 1       Wellington  ...  FUR-CH-10004050        Furniture      Chairs
# 2          Waikato  ...  FUR-TA-10002958        Furniture      Tables
# 3       California  ...  OFF-BI-10003527  Office Supplies     Binders
# 4   North Carolina  ...  FUR-TA-10000198        Furniture      Tables
#
#                                         product_name     sales quantity  \
# 0          Novimex Executive Leather Armchair, Black  3709.395        9
# 1     Novimex Executive Leather Armchair, Adjustable  1822.080        4
# 2       Chromcraft Conference Table, Fully Assembled  5244.840        6
# 3  Fellowes PB500 Electric Punch Plastic Comb Bin...  5083.960        5
# 4  Chromcraft Bull-Nose Wood Oval Conference Tabl...  4297.644       13
#
#   discount     profit  shipping_cost  order_priority
# 0      0.1  -288.7650         923.63        Critical
# 1      0.0   564.8400         894.77        Critical
# 2      0.0   996.4800         878.38            High
# 3      0.2  1906.4850         867.69             Low
# 4      0.4 -1862.3124         865.74        Critical
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### **Maior `>`**
#
# O símbolo `>` significa "maior que", ou seja, selecionaremos todos os registros que sejam maiores do que valor informado.

# %%
# Selecionar todas as linhas onde a quantidade seja maior que 10
consulta = '''
           SELECT quantity
           FROM orders
           WHERE quantity > 10
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#    quantity
# 0        13
# 1        12
# 2        14
# 3        12
# 4        13

# %% [markdown]
# ##### **Maior ou Igual `>=`**
#
# `>=` significa "igual ou maior que", ou seja, selecionaremos todos os registros que sejam iguais ou maiores do que valor informado.

# %%
# Selecionar todas as linhas onde a quantidade seja maior ou igual a 10
consulta = '''
           SELECT quantity
           FROM orders
           WHERE quantity >= 10
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#    quantity
# 0        13
# 1        12
# 2        14
# 3        10
# 4        12

# %% [markdown]
# ##### **Menor `<`**
#
# O símbolo `<` significa "menor que", ou seja, selecionaremos todos os registros que sejam menores do que valor informado.

# %%
# Selecionar todas as linhas onde a quantidade seja menor que 10
consulta = '''
           SELECT quantity
           FROM orders
           WHERE quantity < 10
           LIMIT 10
           '''
executaQuery(consulta)
# Out:
#    quantity
# 0         7
# 1         9
# 2         9
# 3         5
# 4         8
# 5         5
# 6         4
# 7         6
# 8         5
# 9         5

# %% [markdown]
# ##### **Menor ou Igual `<=`**
#
# O símbolo `<=` significa "igual ou menor que", ou seja, selecionaremos todos os registros que sejam iguais ou menores do que valor informado.

# %%
# Selecionar todas as linhas onde a quantidade seja menor ou igual a 10
consulta = '''
           SELECT quantity
           FROM orders
           WHERE quantity <= 10
           LIMIT 10
           '''
executaQuery(consulta)
# Out:
#    quantity
# 0         7
# 1         9
# 2         9
# 3         5
# 4         8
# 5         5
# 6         4
# 7         6
# 8         5
# 9         5

# %% [markdown]
# ##### **BETWEEN**
#
# `BETWEEN` significa "entre", ou seja, selecionaremos todos os registros que estejam entre os valores informados.

# %%
# Selecionar todas as linhas onde valor de venda esteja entre 3000 e 6000
consulta = '''
           SELECT sales
           FROM orders
           WHERE sales BETWEEN 3000 AND 6000
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#       sales
# 0  3709.395
# 1  5175.171
# 2  5244.840
# 3  5083.960
# 4  4297.644

# %% [markdown]
# ##### **AND**
#
# `AND` significa "e", ou seja, podemos concatenar duas ou mais condições, onde ambas tem que ser verdadeiras para que o retorno seja positivo.

# %%
# Selecionar todas as linhas onde a categoria for igual a Technology e a cidade for igual a Valinhos
consulta = '''
           SELECT *
           FROM orders
           WHERE category = 'Technology'
           AND city = 'Valinhos'
           '''
executaQuery(consulta)
# Out:
#    row_id        order_id           order_date            ship_date  \
# 0    5163  MX-2013-132269  2013-06-19 00:00:00  2013-06-23 00:00:00
# 1    9593  MX-2012-140767  2012-02-18 00:00:00  2012-02-22 00:00:00
# 2    9592  MX-2012-140767  2012-02-18 00:00:00  2012-02-22 00:00:00
#
#         ship_mode customer_id       customer_name      segment      city  \
# 0  Standard Class    AS-10090  Adam Shillingsburg     Consumer  Valinhos
# 1  Standard Class    RB-19795          Ross Baird  Home Office  Valinhos
# 2  Standard Class    RB-19795          Ross Baird  Home Office  Valinhos
#
#        state  ...       product_id    category  subcategory  \
# 0  São Paulo  ...  TEC-CO-10004171  Technology      Copiers
# 1  São Paulo  ...  TEC-AC-10000376  Technology  Accessories
# 2  São Paulo  ...  TEC-MA-10004985  Technology     Machines
#
#                      product_name      sales quantity discount     profit  \
# 0   Sharp Fax and Copier, Digital  447.74272        4    0.002  178.54272
# 1       Memorex Router, Bluetooth  820.70000        5    0.000  352.90000
# 2  StarTech Card Printer, Durable  436.32000        4    0.000    4.32000
#
#    shipping_cost  order_priority
# 0         59.641            High
# 1         52.514          Medium
# 2         11.237          Medium
#
# [3 rows x 24 columns]

# %% [markdown]
# ##### **OR**
#
# `AND` significa "ou", ou seja, podemos concatenar duas ou mais condições, onde basta uma das condições ser verdadeira para que o retorno seja positivo.

# %%
# Selecionar todas as linhas onde a categoria for igual a Technology ou a cidade for igual a Valinhos
consulta = '''
           SELECT *
           FROM orders
           WHERE category = 'Technology'
           OR city = 'Valinhos'
           '''
executaQuery(consulta)
# Out:
#        row_id         order_id           order_date            ship_date  \
# 0       32298   CA-2012-124891  2012-07-31 00:00:00  2012-07-31 00:00:00
# 1       25330    IN-2013-71249  2013-10-17 00:00:00  2013-10-18 00:00:00
# 2       13524  ES-2013-1579342  2013-01-28 00:00:00  2013-01-30 00:00:00
# 3       47221     SG-2013-4320  2013-11-05 00:00:00  2013-11-06 00:00:00
# 4       22732    IN-2013-42360  2013-06-28 00:00:00  2013-07-01 00:00:00
# ...       ...              ...                  ...                  ...
# 10142   47992     SU-2014-3390  2014-01-02 00:00:00  2014-01-06 00:00:00
# 10143   35382   CA-2013-111913  2013-08-05 00:00:00  2013-08-07 00:00:00
# 10144   31783   CA-2014-140963  2014-06-11 00:00:00  2014-06-14 00:00:00
# 10145   39396   CA-2013-169663  2013-03-11 00:00:00  2013-03-14 00:00:00
# 10146    9596   MX-2012-140767  2012-02-18 00:00:00  2012-02-22 00:00:00
#
#             ship_mode customer_id     customer_name      segment  \
# 0            Same Day    RH-19495       Rick Hansen     Consumer
# 1         First Class    CR-12730      Craig Reiter     Consumer
# 2         First Class    KM-16375  Katherine Murray  Home Office
# 3            Same Day     RH-9495       Rick Hansen     Consumer
# 4        Second Class    JM-15655       Jim Mitchum    Corporate
# ...               ...         ...               ...          ...
# 10142  Standard Class     JM-5250      Janet Martin     Consumer
# 10143    Second Class    LC-16930    Linda Cazamias    Corporate
# 10144     First Class    MT-18070     Michelle Tran  Home Office
# 10145     First Class    RH-19510    Rick Huthwaite  Home Office
# 10146  Standard Class    RB-19795        Ross Baird  Home Office
#
#                 city            state  ...        product_id         category  \
# 0      New York City         New York  ...   TEC-AC-10003033       Technology
# 1           Brisbane       Queensland  ...   TEC-PH-10004664       Technology
# 2             Berlin           Berlin  ...   TEC-PH-10004583       Technology
# 3              Dakar            Dakar  ...  TEC-SHA-10000501       Technology
# 4             Sydney  New South Wales  ...   TEC-PH-10000030       Technology
# ...              ...              ...  ...               ...              ...
# 10142      Bur Sudan          Red Sea  ...  TEC-MOT-10001088       Technology
# 10143     Sacramento       California  ...   TEC-PH-10002275       Technology
# 10144    Los Angeles       California  ...   TEC-PH-10001924       Technology
# 10145    Los Angeles       California  ...   TEC-AC-10003038       Technology
# 10146       Valinhos        São Paulo  ...   OFF-BI-10000806  Office Supplies
#
#        subcategory                                       product_name  \
# 0      Accessories  Plantronics CS510 - Over-the-Head monaural Wir...
# 1           Phones                  Nokia Smart Phone, with Caller ID
# 2           Phones                     Motorola Smart Phone, Cordless
# 3          Copiers                     Sharp Wireless Fax, High-Speed
# 4           Phones                Samsung Smart Phone, with Caller ID
# ...            ...                                                ...
# 10142       Phones                          Motorola Audio Dock, VoIP
# 10143       Phones                     Mitel 5320 IP Phone VoIP phone
# 10144       Phones           iHome FM Clock Radio with Lightning Dock
# 10145  Accessories         Kingston Digital DataTraveler 16GB USB 2.0
# 10146      Binders                            Acco Index Tab, Economy
#
#           sales quantity discount    profit  shipping_cost  order_priority
# 0      2309.650        7      0.0  762.1845        933.570        Critical
# 1      5175.171        9      0.1  919.9710        915.490          Medium
# 2      2892.510        5      0.1  -96.5400        910.160          Medium
# 3      2832.960        8      0.0  311.5200        903.040        Critical
# 4      2862.675        5      0.1  763.2750        897.350        Critical
# ...         ...      ...      ...       ...            ...             ...
# 10142   173.460        1      0.0   50.2800          0.090          Medium
# 10143   302.384        2      0.2   30.2384          0.060          Medium
# 10144   279.960        5      0.2   17.4975          0.050            High
# 10145    26.850        3      0.0    5.1015          0.040          Medium
# 10146    13.440        2      0.0    2.4000          0.003          Medium
#
# [10147 rows x 24 columns]

# %% [markdown]
# ##### **IN**
#
# `IN` significa "em", ou seja, retorna todos os valores que estejam dentro de uma lista de opções informadas atraves de uma lista.

# %%
# Selecionar todas os registros que sejam das cidades de New York City e Berlin
consulta = '''
           SELECT *
           FROM orders
           WHERE city IN ('New York City', 'Berlin')
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#    row_id         order_id           order_date            ship_date  \
# 0   32298   CA-2012-124891  2012-07-31 00:00:00  2012-07-31 00:00:00
# 1   13524  ES-2013-1579342  2013-01-28 00:00:00  2013-01-30 00:00:00
# 2   36423   CA-2011-160766  2011-09-14 00:00:00  2011-09-14 00:00:00
# 3   15953  IT-2011-3183678  2011-09-23 00:00:00  2011-09-25 00:00:00
# 4   40046   US-2012-163825  2012-06-16 00:00:00  2012-06-19 00:00:00
#
#      ship_mode customer_id     customer_name      segment           city  \
# 0     Same Day    RH-19495       Rick Hansen     Consumer  New York City
# 1  First Class    KM-16375  Katherine Murray  Home Office         Berlin
# 2     Same Day    DM-13015     Darrin Martin     Consumer  New York City
# 3  First Class    ZC-21910  Zuschuss Carroll     Consumer         Berlin
# 4  First Class    LC-16885    Lena Creighton     Consumer  New York City
#
#       state  ...       product_id         category  subcategory  \
# 0  New York  ...  TEC-AC-10003033       Technology  Accessories
# 1    Berlin  ...  TEC-PH-10004583       Technology       Phones
# 2  New York  ...  TEC-MA-10003979       Technology     Machines
# 3    Berlin  ...  OFF-AP-10000486  Office Supplies   Appliances
# 4  New York  ...  OFF-BI-10003527  Office Supplies      Binders
#
#                                         product_name     sales quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1                     Motorola Smart Phone, Cordless  2892.510        5
# 2                  Ativa V4110MDD Micro-Cut Shredder  2799.960        4
# 3                            Cuisinart Stove, Silver  3018.624        7
# 4  Fellowes PB500 Electric Punch Plastic Comb Bin...  3050.376        3
#
#   discount     profit  shipping_cost  order_priority
# 0      0.0   762.1845         933.57        Critical
# 1      0.1   -96.5400         910.16          Medium
# 2      0.0  1371.9804         675.15            High
# 3      0.2   377.2440         655.91        Critical
# 4      0.2  1143.8910         632.05            High
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### **NOT**
#
# `NOT` significa "negação", ou seja, tem efeito de trazer o inverso de qualquer condição posterior a ele.

# %%
# Selecionar todas as linhas que não sejam das cidades de New York City e Berlin
consulta = '''
           SELECT *
           FROM orders
           WHERE city NOT IN ('New York City', 'Berlin')
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#    row_id       order_id           order_date            ship_date  \
# 0   26341  IN-2013-77878  2013-02-05 00:00:00  2013-02-07 00:00:00
# 1   25330  IN-2013-71249  2013-10-17 00:00:00  2013-10-18 00:00:00
# 2   47221   SG-2013-4320  2013-11-05 00:00:00  2013-11-06 00:00:00
# 3   22732  IN-2013-42360  2013-06-28 00:00:00  2013-07-01 00:00:00
# 4   30570  IN-2011-81826  2011-11-07 00:00:00  2011-11-09 00:00:00
#
#       ship_mode customer_id  customer_name    segment        city  \
# 0  Second Class    JR-16210  Justin Ritter  Corporate  Wollongong
# 1   First Class    CR-12730   Craig Reiter   Consumer    Brisbane
# 2      Same Day     RH-9495    Rick Hansen   Consumer       Dakar
# 3  Second Class    JM-15655    Jim Mitchum  Corporate      Sydney
# 4   First Class    TS-21340  Toby Swindell   Consumer     Porirua
#
#              state  ...        product_id    category subcategory  \
# 0  New South Wales  ...   FUR-CH-10003950   Furniture      Chairs
# 1       Queensland  ...   TEC-PH-10004664  Technology      Phones
# 2            Dakar  ...  TEC-SHA-10000501  Technology     Copiers
# 3  New South Wales  ...   TEC-PH-10000030  Technology      Phones
# 4       Wellington  ...   FUR-CH-10004050   Furniture      Chairs
#
#                                      product_name     sales quantity discount  \
# 0       Novimex Executive Leather Armchair, Black  3709.395        9      0.1
# 1               Nokia Smart Phone, with Caller ID  5175.171        9      0.1
# 2                  Sharp Wireless Fax, High-Speed  2832.960        8      0.0
# 3             Samsung Smart Phone, with Caller ID  2862.675        5      0.1
# 4  Novimex Executive Leather Armchair, Adjustable  1822.080        4      0.0
#
#     profit  shipping_cost  order_priority
# 0 -288.765         923.63        Critical
# 1  919.971         915.49          Medium
# 2  311.520         903.04        Critical
# 3  763.275         897.35        Critical
# 4  564.840         894.77        Critical
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### **LIKE**
#
# `LIKE` é utilizado em conjunto com a cláusula `WHERE` e serve para realizar uma busca mais refinada em um campo de uma tabela.
#
# **Sintaxe:**
#
# ```
# SELECT coluna1, coluna2, ... colunaN
#   FROM nome_da_tabela
# WHERE nome_coluna LIKE modelo;
# ```
#
# Existem dois curingas frequentemente usados ​​em conjunto com o LIKE:
#
#  1. O sinal de porcentagem (```%```) representa zero, um ou vários caracteres;
#  2. O sinal de sublinhado (```_```) representa um único caractere.
#
#  Para exemplos do uso de LIKE, veja este [tutorial da W3 Schools](https://www.w3schools.com/sql/sql_like.asp).

# %%
# Selecionando todas as linhas em que o nome começa com a letra "P" ("P" maiúsculo)
consulta = '''
           SELECT customer_name name
           FROM orders
           WHERE customer_name LIKE 'P%'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#                 name
# 0       Peter Fuller
# 1      Patrick Jones
# 2     Phillip Breyer
# 3  Patrick O'Donnell
# 4     Phillip Breyer

# %%
# Selecionar todas as linhas em que o nome termina com a letra "a" ("a" minúsculo)
consulta = '''
           SELECT customer_name name
           FROM orders
           WHERE customer_name LIKE '%a'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#              name
# 0      Dan Lawera
# 1    Dario Medina
# 2   Maribeth Dona
# 3  Helen Andreada
# 4    Dario Medina

# %%
# Selecionando todas as linhas em que o nome contenha os caracteres 'oa' em qualquer lugar do termo
consulta = '''
           SELECT customer_name name
           FROM orders
           WHERE customer_name LIKE '%oa%'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#              name
# 0     Noah Childs
# 1     Noah Childs
# 2  Pamela Coakley
# 3     Noah Childs
# 4  Pamela Coakley

# %%
# Selecionando todas as linhas em que o nome tem a segunda letra sendo "r" ("r" minúsculo)
consulta = '''
           SELECT customer_name
           FROM orders
           WHERE customer_name LIKE '_r%'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#     customer_name
# 0    Craig Reiter
# 1    Greg Maxwell
# 2  Grant Thornton
# 3       Greg Tran
# 4  Arthur Prichep

# %%
# Selecionando todas as linhas em que o nome começa com a letra 'P', tenham 2 caracteres e logo depois a letra 'r'
consulta = '''
           SELECT customer_name name
           FROM orders
           WHERE customer_name LIKE 'P__r%'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#                 name
# 0      Patrick Jones
# 1  Patrick O'Donnell
# 2    Patrick O'Brill
# 3  Patrick O'Donnell
# 4    Patrick Bzostek

# %%
# Selecionar todas as linhas que o nome dos consumidores comecem com a letra 'P' e terminem com a letra 'g'
consulta = '''
           SELECT customer_name name
           FROM orders
           WHERE customer_name LIKE 'P%g'
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#              name
# 0  Pete Armstrong
# 1  Pete Armstrong
# 2  Pete Armstrong
# 3  Pete Armstrong
# 4  Pete Armstrong

# %% [markdown]
# #### **DISTINCT**
#
# ```DISTINCT``` permite analisar os valores únicos de uma coluna.

# %%
# Selecionando todas as categorias únicas
consulta = '''
          SELECT DISTINCT category
           FROM orders
           '''
executaQuery(consulta)
# Out:
#           category
# 0       Technology
# 1        Furniture
# 2  Office Supplies

# %% [markdown]
# #### **Aggregate Functions**
#
# Funções de agregação são funções SQL que permitem executar uma operação aritmética nos valores de uma coluna para todos os registros de uma tabela.
#
# São compostas por `MAX`, `MIN`, `AVG`, `SUM` e `COUNT`. Cada uma delas executa uma tarefa específica.

# %% [markdown]
# ##### **MAX**
#
# Retorna o maior valor da coluna selecionada.

# %%
# Retorna o valor máximo de custo de frete
consulta = '''
           SELECT MAX(shipping_cost) AS max_shippingcost
           FROM orders
           '''
executaQuery(consulta)
# Out:
#    max_shippingcost
# 0            933.57

# %% [markdown]
# ##### **MIN**
#
# Retorna o menor valor da coluna selecionada.

# %%
# Retorna o valor mínimo de custo de frete
consulta = '''
           SELECT MIN(shipping_cost) AS min_shippingcost
           FROM orders
           '''
executaQuery(consulta)
# Out:
#    min_shippingcost
# 0             0.002

# %% [markdown]
# ##### **AVG**
#
# Retorna a média de uma coluna numérica.

# %%
# Retorna o valor médio de custo de frete
consulta = '''
           SELECT AVG(shipping_cost) AS avg_shippingcost
           FROM orders
           '''
executaQuery(consulta)
# Out:
#    avg_shippingcost
# 0         26.375818

# %% [markdown]
# ##### **SUM**
#
# Retorna a soma total de uma coluna numérica.

# %%
# Retorna o valor total de custo de frete
consulta = '''
           SELECT ROUND(SUM(shipping_cost),3) AS total_shippingcost
           FROM orders
           '''
executaQuery(consulta)
# Out:
#    total_shippingcost
# 0         1352815.703

# %% [markdown]
# ##### **COUNT**
# Retorna o número de linhas que corresponde a um critério especificado.

# %%
# Retorna o número total de ordens na tabela
consulta = '''
          SELECT COUNT(*) AS total_orders
           FROM orders
           '''
executaQuery(consulta)
# Out:
#    total_orders
# 0         51290

# %%
# Retornar o numéros distintos de tipos de frete existentes na tabela
consulta = '''
          SELECT COUNT(DISTINCT ship_mode) AS total_shipmode
           FROM orders
           '''
executaQuery(consulta)
# Out:
#    total_shipmode
# 0               4

# %% [markdown]
# #### **ORDER BY**
#
# `ORDER BY` é usado para classificar resultados de uma consulta em ordem crescente ou decrescente.
#
# Ela classifica os registros em ordem crescente (como A-Z ou de um número menor para um maior) por padrão (`ASC`).
#
# Para classificar os registros em ordem decrescente (como de Z-A ou de um número maior para um menor), use a palavra `DESC`.

# %%
# Seleciona todas as linhas ordenandas pelo maior número de vendas para o menor
consulta = '''
           SELECT sales
           FROM orders
           ORDER BY sales DESC
           LIMIT 5
           '''
executaQuery(consulta)
# Out:
#        sales
# 0  22638.480
# 1  17499.950
# 2  13999.960
# 3  11199.968
# 4  10499.970

# %% [markdown]
# #### **GROUP BY**
#
# `GROUP BY` é a instrução que agrupa as linhas que têm os mesmos valores em linhas de resumo.
#
# É frequentemente usada com funções agregadas `COUNT()`, `MAX()`, `MIN()`, `SUM()`e `AVG()` para agrupar resultados de uma consulta por uma ou mais colunas.

# %%
# Retorna o valor total de vendas agrupadas pelo tipo de frete
consulta = '''
          SELECT ship_mode,
                 ROUND(SUM(sales),2) as total_sales
          FROM orders
          GROUP BY ship_mode

           '''
executaQuery(consulta)
# Out:
#         ship_mode  total_sales
# 0     First Class   1830976.14
# 1        Same Day    667201.98
# 2    Second Class   2565671.68
# 3  Standard Class   7578652.11

# %%
# Retorna o número total de vendas agrupadas pelo tipo de frete
consulta = '''
          SELECT ship_mode,
                 COUNT(sales) as total_sales
          FROM orders
          GROUP BY ship_mode

           '''
executaQuery(consulta)
# Out:
#         ship_mode  total_sales
# 0     First Class         7505
# 1        Same Day         2701
# 2    Second Class        10309
# 3  Standard Class        30775

# %%
# Retorna a quantidade de registros por categoria
consulta = '''
          SELECT category,
                 COUNT(*) as quantidade
          FROM orders
          GROUP BY category

           '''
executaQuery(consulta)
# Out:
#           category  quantidade
# 0        Furniture        9876
# 1  Office Supplies       31273
# 2       Technology       10141

# %% [markdown]
# #### **JOIN**
#
# `JOIN` é usado para combinar linhas de duas ou mais tabelas, com base em uma coluna relacionada entre elas.
#
# Há diferentes tipos de JOIN no SQL:
#
# 1. `(INNER) JOIN`: Retorna registros que possuem valores correspondentes em ambas as tabelas
# 2. `LEFT (OUTER) JOIN`: Retorna todos os registros da tabela da esquerda e os registros correspondentes da tabela da direita
# 3. `RIGHT (OUTER) JOIN`: Retorna todos os registros da tabela da direita e os registros correspondentes da tabela da esquerda
# 4. `FULL (OUTER) JOIN`: Retorna todos os registros quando há uma correspondência na tabela à esquerda ou à direita.
#
# [Esta imagem](https://i.pinimg.com/736x/50/89/6f/50896fa027cb4fa4829c87c8c2dfc054--sql-join-sql-server.jpg) ajuda a entender melhor como os diferentes tipos de JOINs funcionam. Se você já viu algo sobre Teoria de Conjuntos, isto será familiar.

# %% [markdown]
# ###### **INNER JOIN**

# %%
consulta = '''
          SELECT *
          FROM orders AS o
          INNER JOIN returns AS r
          ON o.order_id = r.order_id

           '''
executaQuery(consulta)
# Out:
#       row_id         order_id           order_date            ship_date  \
# 0      26341    IN-2013-77878  2013-02-05 00:00:00  2013-02-07 00:00:00
# 1      12069  ES-2014-1651774  2014-09-08 00:00:00  2014-09-14 00:00:00
# 2      22999    IN-2012-44810  2012-02-25 00:00:00  2012-02-25 00:00:00
# 3      32735   CA-2012-139731  2012-10-15 00:00:00  2012-10-15 00:00:00
# 4      36423   CA-2011-160766  2011-09-14 00:00:00  2011-09-14 00:00:00
# ...      ...              ...                  ...                  ...
# 3050   33548   CA-2012-116092  2012-02-15 00:00:00  2012-02-18 00:00:00
# 3051   31783   CA-2014-140963  2014-06-11 00:00:00  2014-06-14 00:00:00
# 3052   37087   CA-2014-140186  2014-09-30 00:00:00  2014-10-03 00:00:00
# 3053    6367   MX-2011-131688  2011-12-22 00:00:00  2011-12-26 00:00:00
# 3054   29002    IN-2014-62366  2014-06-19 00:00:00  2014-06-19 00:00:00
#
#            ship_mode customer_id       customer_name      segment  \
# 0       Second Class    JR-16210       Justin Ritter    Corporate
# 1     Standard Class    PJ-18835       Patrick Jones    Corporate
# 2           Same Day    BP-11230  Benjamin Patterson     Consumer
# 3           Same Day    JE-15745          Joel Eaton     Consumer
# 4           Same Day    DM-13015       Darrin Martin     Consumer
# ...              ...         ...                 ...          ...
# 3050    Second Class    JM-16195  Justin MacKendrick     Consumer
# 3051     First Class    MT-18070       Michelle Tran  Home Office
# 3052     First Class    PG-18820     Patrick Gardner     Consumer
# 3053  Standard Class    BP-11230  Benjamin Patterson     Consumer
# 3054        Same Day    KE-16420     Katrina Edelman    Corporate
#
#                city            state  ...  \
# 0        Wollongong  New South Wales  ...
# 1             Prato          Tuscany  ...
# 2             Surat          Gujarat  ...
# 3          Amarillo            Texas  ...
# 4     New York City         New York  ...
# ...             ...              ...  ...
# 3050    Los Angeles       California  ...
# 3051    Los Angeles       California  ...
# 3052    Bakersfield       California  ...
# 3053         Toluca           México  ...
# 3054           Kure        Hiroshima  ...
#
#                                       product_name     sales quantity  \
# 0        Novimex Executive Leather Armchair, Black  3709.395        9
# 1                                Hoover Stove, Red  7958.580       14
# 2      Office Star Executive Leather Armchair, Red  1878.720        4
# 3     HON 5400 Series Task Chairs for Big and Tall  2453.430        5
# 4                Ativa V4110MDD Micro-Cut Shredder  2799.960        4
# ...                                            ...       ...      ...
# 3050                                      Xerox 22    19.440        3
# 3051      iHome FM Clock Radio with Lightning Dock   279.960        5
# 3052                  Advantus Plastic Paper Clips    35.000        7
# 3053                  Acco Binder Covers, Recycled    36.480        4
# 3054                 Advantus Thumb Tacks, 12 Pack    65.100        5
#
#      discount     profit shipping_cost order_priority returned  \
# 0         0.1  -288.7650       923.630       Critical      Yes
# 1         0.0  3979.0800       778.320            Low      Yes
# 2         0.0   582.3600       704.080       Critical      Yes
# 3         0.3  -350.4900       690.420           High      Yes
# 4         0.0  1371.9804       675.150           High      Yes
# ...       ...        ...           ...            ...      ...
# 3050      0.0     9.3312         0.060         Medium      Yes
# 3051      0.2    17.4975         0.050           High      Yes
# 3052      0.0    16.8000         0.040         Medium      Yes
# 3053      0.0     3.2800         0.039         Medium      Yes
# 3054      0.0     4.5000         0.010         Medium      Yes
#
#              order_id         market
# 0       IN-2013-77878           APAC
# 1     ES-2014-1651774             EU
# 2       IN-2012-44810           APAC
# 3      CA-2012-139731  United States
# 4      CA-2011-160766  United States
# ...               ...            ...
# 3050   CA-2012-116092  United States
# 3051   CA-2014-140963  United States
# 3052   CA-2014-140186  United States
# 3053   MX-2011-131688          LATAM
# 3054    IN-2014-62366           APAC
#
# [3055 rows x 27 columns]

# %% [markdown]
# ###### **LEFT JOIN**

# %%
consulta = '''
          SELECT *
          FROM orders AS o
          LEFT JOIN returns AS r
          ON o.order_id = r.order_id

           '''
executaQuery(consulta)
# Out:
#        row_id         order_id           order_date            ship_date  \
# 0       32298   CA-2012-124891  2012-07-31 00:00:00  2012-07-31 00:00:00
# 1       26341    IN-2013-77878  2013-02-05 00:00:00  2013-02-07 00:00:00
# 2       25330    IN-2013-71249  2013-10-17 00:00:00  2013-10-18 00:00:00
# 3       13524  ES-2013-1579342  2013-01-28 00:00:00  2013-01-30 00:00:00
# 4       47221     SG-2013-4320  2013-11-05 00:00:00  2013-11-06 00:00:00
# ...       ...              ...                  ...                  ...
# 51290   29002    IN-2014-62366  2014-06-19 00:00:00  2014-06-19 00:00:00
# 51291   35398   US-2014-102288  2014-06-20 00:00:00  2014-06-24 00:00:00
# 51292   40470   US-2013-155768  2013-12-02 00:00:00  2013-12-02 00:00:00
# 51293    9596   MX-2012-140767  2012-02-18 00:00:00  2012-02-22 00:00:00
# 51294    6147   MX-2012-134460  2012-05-22 00:00:00  2012-05-26 00:00:00
#
#             ship_mode customer_id     customer_name      segment  \
# 0            Same Day    RH-19495       Rick Hansen     Consumer
# 1        Second Class    JR-16210     Justin Ritter    Corporate
# 2         First Class    CR-12730      Craig Reiter     Consumer
# 3         First Class    KM-16375  Katherine Murray  Home Office
# 4            Same Day     RH-9495       Rick Hansen     Consumer
# ...               ...         ...               ...          ...
# 51290        Same Day    KE-16420   Katrina Edelman    Corporate
# 51291  Standard Class    ZC-21910  Zuschuss Carroll     Consumer
# 51292        Same Day    LB-16795    Laurel Beltran  Home Office
# 51293  Standard Class    RB-19795        Ross Baird  Home Office
# 51294    Second Class    MC-18100     Mick Crebagga     Consumer
#
#                 city            state  ...  \
# 0      New York City         New York  ...
# 1         Wollongong  New South Wales  ...
# 2           Brisbane       Queensland  ...
# 3             Berlin           Berlin  ...
# 4              Dakar            Dakar  ...
# ...              ...              ...  ...
# 51290           Kure        Hiroshima  ...
# 51291        Houston            Texas  ...
# 51292         Oxnard       California  ...
# 51293       Valinhos        São Paulo  ...
# 51294       Tipitapa          Managua  ...
#
#                                             product_name     sales quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51290                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51291  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51292       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51293                            Acco Index Tab, Economy    13.440        2
# 51294            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       discount    profit shipping_cost order_priority returned       order_id  \
# 0          0.0  762.1845       933.570       Critical     None           None
# 1          0.1 -288.7650       923.630       Critical      Yes  IN-2013-77878
# 2          0.1  919.9710       915.490         Medium     None           None
# 3          0.1  -96.5400       910.160         Medium     None           None
# 4          0.0  311.5200       903.040       Critical     None           None
# ...        ...       ...           ...            ...      ...            ...
# 51290      0.0    4.5000         0.010         Medium      Yes  IN-2014-62366
# 51291      0.8   -1.1100         0.010         Medium     None           None
# 51292      0.0   11.2308         0.010           High     None           None
# 51293      0.0    2.4000         0.003         Medium     None           None
# 51294      0.0    1.8000         0.002           High     None           None
#
#        market
# 0        None
# 1        APAC
# 2        None
# 3        None
# 4        None
# ...       ...
# 51290    APAC
# 51291    None
# 51292    None
# 51293    None
# 51294    None
#
# [51295 rows x 27 columns]

# %%
consulta = '''
          SELECT *
          FROM returns AS r
          LEFT JOIN orders AS o
          ON o.order_id = r.order_id

           '''
executaQuery(consulta)
# Out:
#      returned         order_id         market  row_id         order_id  \
# 0         Yes   MX-2013-168137          LATAM    1620   MX-2013-168137
# 1         Yes   MX-2013-168137          LATAM    1621   MX-2013-168137
# 2         Yes   US-2011-165316          LATAM    4251   US-2011-165316
# 3         Yes   US-2011-165316          LATAM    4252   US-2011-165316
# 4         Yes   US-2011-165316          LATAM    4253   US-2011-165316
# ...       ...              ...            ...     ...              ...
# 3050      Yes  ES-2012-4379168             EU   14381  ES-2012-4379168
# 3051      Yes  ES-2012-4379168             EU   14382  ES-2012-4379168
# 3052      Yes  ES-2012-4379168             EU   14383  ES-2012-4379168
# 3053      Yes   CA-2014-168193  United States   35031   CA-2014-168193
# 3054      Yes   CA-2014-168193  United States   35032   CA-2014-168193
#
#                order_date            ship_date       ship_mode customer_id  \
# 0     2013-11-06 00:00:00  2013-11-08 00:00:00     First Class    AB-10105
# 1     2013-11-06 00:00:00  2013-11-08 00:00:00     First Class    AB-10105
# 2     2011-06-18 00:00:00  2011-06-23 00:00:00    Second Class    LO-17170
# 3     2011-06-18 00:00:00  2011-06-23 00:00:00    Second Class    LO-17170
# 4     2011-06-18 00:00:00  2011-06-23 00:00:00    Second Class    LO-17170
# ...                   ...                  ...             ...         ...
# 3050  2012-02-22 00:00:00  2012-02-26 00:00:00  Standard Class    DV-13465
# 3051  2012-02-22 00:00:00  2012-02-26 00:00:00  Standard Class    DV-13465
# 3052  2012-02-22 00:00:00  2012-02-26 00:00:00  Standard Class    DV-13465
# 3053  2014-03-07 00:00:00  2014-03-12 00:00:00    Second Class    RM-19750
# 3054  2014-03-07 00:00:00  2014-03-12 00:00:00    Second Class    RM-19750
#
#          customer_name  ...       product_id         category  subcategory  \
# 0        Adrian Barton  ...  OFF-AP-10004569  Office Supplies   Appliances
# 1        Adrian Barton  ...  OFF-BI-10002799  Office Supplies      Binders
# 2           Lori Olson  ...  FUR-FU-10004458        Furniture  Furnishings
# 3           Lori Olson  ...  OFF-LA-10004947  Office Supplies       Labels
# 4           Lori Olson  ...  OFF-SU-10000085  Office Supplies     Supplies
# ...                ...  ...              ...              ...          ...
# 3050  Dianna Vittorini  ...  TEC-AC-10001904       Technology  Accessories
# 3051  Dianna Vittorini  ...  OFF-LA-10002353  Office Supplies       Labels
# 3052  Dianna Vittorini  ...  OFF-PA-10004343  Office Supplies        Paper
# 3053     Roland Murray  ...  OFF-PA-10002254  Office Supplies        Paper
# 3054     Roland Murray  ...  FUR-FU-10002554        Furniture  Furnishings
#
#                                            product_name   sales quantity  \
# 0                            Hoover Coffee Grinder, Red  137.58        3
# 1                          Acco Binder Covers, Recycled   63.84        7
# 2                           Rubbermaid Door Stop, Black   70.08        4
# 3                   Hon Shipping Labels, 5000 Label Set   15.68        2
# 4                               Kleencut Trimmer, Steel  136.10        5
# ...                                                 ...     ...      ...
# 3050                          Logitech Mouse, Bluetooth  204.96        7
# 3051  Harbour Creations Legal Exhibit Labels, Laser ...   54.75        5
# 3052                        Enermax Memo Slips, Premium   46.98        3
# 3053                                         Xerox 1883   26.38        1
# 3054  Westinghouse Floor Lamp with Metal Mesh Shade,...   71.97        3
#
#      discount   profit shipping_cost order_priority
# 0         0.0  27.4800        37.099       Critical
# 1         0.0   5.7400        16.158       Critical
# 2         0.4  -5.8400         2.235           High
# 3         0.0   6.5600         2.790           High
# 4         0.0  50.3000        12.853           High
# ...       ...      ...           ...            ...
# 3050      0.0  92.1900        19.130         Medium
# 3051      0.0  12.0000         2.630         Medium
# 3052      0.0   0.9000         4.380         Medium
# 3053      0.0  12.1348         5.420           High
# 3054      0.0  16.5531        10.550           High
#
# [3055 rows x 27 columns]

# %% [markdown]
# ## **5. Considerações**
#
# Vimos um bocado de conceitos. Procure repassá-los e praticá-los. Com o tempo, você verá que muitas coisas que podem ser feitas diretamente com SQL também podem ser feitas com Pandas (ou vice-e-versa). As ideias são as mesmas; as ferramentas e sintaxe de comandos é que mudam.
#
# Recomendamos que você siga estudando e consultando este [tutorial da W2 Schools](https://www.w3schools.com/sql/default.asp) e este outro, do [SQL Tutorial](https://www.sqltutorial.org/), para ir se familizarizando com SQL e para entender como um comando funciona.
#
# Em startups e empresas mais maduras, talvez você já receba dados prontos e formatados da Engenharia de Dados, por meio de CSV, JSON ou APIs, para uso direto com Pandas. No entanto, talvez nem todos os locais tenham essas facilidades e você terá acesso a ler bancos de dados diretamente. Saber SQL é um diferencial nessas situações.

# %% [markdown]
# ---
#
# Notebook utilizado para fins educacionais da **Awari**.
#
# **© AWARI. Todos os direitos reservados.**
